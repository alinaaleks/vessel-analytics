# %%
import pandas as pd

# %%
df = pd.read_csv("../data/csv/vessels.csv", encoding="utf-8")

df.head(2)
# Out:
#    vessel_id              name  shipped_mt loading_port loading_date  \
# 0          1  MV RIVER VOYAGER  6231.82464         Азов   2023-08-30
# 1          2       NEVSKIY 214  5751.95973         Азов   2023-09-07
#
#       discharge_port  project_id
# 0  Alexandria, Egypt           1
# 1  Alexandria, Egypt           1
